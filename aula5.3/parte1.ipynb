# %%
! pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.10.2-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.7 MB 960.0 kB/s eta 0:00:02
#      ---- ----------------------------------- 0.2/1.7 MB 2.1 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.5/1.7 MB 3.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.0/1.7 MB 5.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 8.5 MB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2026.7.19-cp310-cp310-win_amd64.whl (277 kB)
#      ---------------------------------------- 0.0/278.0 kB ? eta -:--:--
#      ------------------------------------- 278.0/278.0 kB 16.7 MB/s eta 0:00:00
# Collecting click
#   Downloading click-8.4.2-py3-none-any.whl (119 kB)
#      ---------------------------------------- 0.0/119.2 kB ? eta -:--:--
#      -------------------------------------- 119.2/119.2 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\diogo\onedrive\documentos\introducaomachinelearningdell\aula5.3\.venv\lib\site-packages (from nltk) (1.5.3)
# Collecting tqdm
#   Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
#      ---------------------------------------- 0.0/80.2 kB ? eta -:--:--
#      ---------------------------------------- 80.2/80.2 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: defusedxml in c:\users\diogo\onedrive\documentos\introducaomachinelearningdell\aula5.3\.venv\lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: colorama in c:\users\diogo\onedrive\documentos\introducaomachinelearningdell\aula5.3\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.4.2 nltk-3.10.2 regex-2026.7.19 tqdm-4.70.0
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\diogo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
print(stopwords)
# Out:
# ['a', 'à', 'ao', 'aos', 'aquela', 'aquelas', 'aquele', 'aqueles', 'aquilo', 'as', 'às', 'até', 'com', 'como', 'da', 'das', 'de', 'dela', 'delas', 'dele', 'deles', 'depois', 'do', 'dos', 'e', 'é', 'ela', 'elas', 'ele', 'eles', 'em', 'entre', 'era', 'eram', 'éramos', 'essa', 'essas', 'esse', 'esses', 'esta', 'está', 'estamos', 'estão', 'estar', 'estas', 'estava', 'estavam', 'estávamos', 'este', 'esteja', 'estejam', 'estejamos', 'estes', 'esteve', 'estive', 'estivemos', 'estiver', 'estivera', 'estiveram', 'estivéramos', 'estiverem', 'estivermos', 'estivesse', 'estivessem', 'estivéssemos', 'estou', 'eu', 'foi', 'fomos', 'for', 'fora', 'foram', 'fôramos', 'forem', 'formos', 'fosse', 'fossem', 'fôssemos', 'fui', 'há', 'haja', 'hajam', 'hajamos', 'hão', 'havemos', 'haver', 'hei', 'houve', 'houvemos', 'houver', 'houvera', 'houverá', 'houveram', 'houvéramos', 'houverão', 'houverei', 'houverem', 'houveremos', 'houveria', 'houveriam', 'houveríamos', 'houvermos', 'houvesse', 'houvessem', 'houvéssemos', 'isso', 'isto', 'já', 'lhe', 'lhes', 'mais', 'mas', 'me', 'mesmo', 'meu', 'meus', 'minha', 'minhas', 'muito', 'na', 'não', 'nas', 'nem', 'no', 'nos', 'nós', 'nossa', 'nossas', 'nosso', 'nossos', 'num', 'numa', 'o', 'os', 'ou', 'para', 'pela', 'pelas', 'pelo', 'pelos', 'por', 'qual', 'quando', 'que', 'quem', 'são', 'se', 'seja', 'sejam', 'sejamos', 'sem', 'ser', 'será', 'serão', 'serei', 'seremos', 'seria', 'seriam', 'seríamos', 'seu', 'seus', 'só', 'somos', 'sou', 'sua', 'suas', 'também', 'te', 'tem', 'tém', 'temos', 'tenha', 'tenham', 'tenhamos', 'tenho', 'terá', 'terão', 'terei', 'teremos', 'teria', 'teriam', 'teríamos', 'teu', 'teus', 'teve', 'tinha', 'tinham', 'tínhamos', 'tive', 'tivemos', 'tiver', 'tivera', 'tiveram', 'tivéramos', 'tiverem', 'tivermos', 'tivesse', 'tivessem', 'tivéssemos', 'tu', 'tua', 'tuas', 'um', 'uma', 'você', 'vocês', 'vos']

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\diogo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
frase = 'Eu dirijo devagar porque nós queremos ver os animais.'

# %%
tokens = word_tokenize(frase)

# %%
print(tokens)
# Out:
# ['Eu', 'dirijo', 'devagar', 'porque', 'nós', 'queremos', 'ver', 'os', 'animais', '.']

# %%
for t in tokens:
    if t not in stopwords:
        print(t)
# Out:
# Eu
# dirijo
# devagar
# porque
# queremos
# ver
# animais
# .
